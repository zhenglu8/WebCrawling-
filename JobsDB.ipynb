# %%
from bs4 import BeautifulSoup
import requests
import csv

# %%
source = requests.get('https://sg.jobsdb.com/j?sp=homepage&q=&l=Singapore').text
soup = BeautifulSoup(source, 'lxml')

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="midori" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=Edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0, viewport-fit=cover" name="viewport"/>
#   <meta content="#000000" name="theme-color"/>
#   <meta content="authenticity_token" name="csrf-param"/>
#   <meta content="EHqfTRv9I2YzOzUbo8YCXqIYYFQY4SKJ4NEc/q7DZmOAOiz8w+ErnYwrT1dCBzuXXDw9vPep/kDinLgqWrt5Aw==" name="csrf-token"/>
#   <link href="https://jora-assets.jora.com/assets/sg/sg-favicon-13ae1ce854eb27638e48654ca3f0173d4744d0d8eb8bb100a06d36b8c8169456.png" rel="shortcut icon" type="image/x-icon"/>
#   <title>
#    Jobs in Singapore - February 2021 | jobsDB
#   </title>
#   <meta content="View 173,199 Jobs in Singapore at jobsDB, create free email alerts and never miss another career opportunity again." name="description"/>
#   <link href="https://sg.jobsdb.com/jobs-in-Singapore" rel="canonical"/>
#   <link href="https://jora-assets.jora.com/assets/packs/css/application-9b222d09.css" media="screen" rel="stylesheet"/>
#   <script>
#    window.JobEngine = window.JobEngine || {};
#   </script>
#   <script async="async" src="//www.google.com/adsense/search/ads.js">
#   </script>
#  </head>
#  <body class="site-sg midori">
#   <header class="site-header">
#    <div class="header-left-column">
#     <a class="homepage-link" href="/" title="jobsDB">
#      <svg class="jora-logo header" viewbox="0 0 148 32" xmlns="http://www.w3.org/2000/svg">
#       <path class="text" d="M54.935.193v11.538c1.604-2.05 3.967-3.252 7.22-3.252 5.972 0 10.875 5.123 10.875 11.76C73.03 26.877 68.127 32 62.155 32c-3.253 0-5.616-1.203-7.22-3.252v2.628h-5.75V.193h5.75zm-19.46 8.085c6.552 0 11.81 5.123 11.81 11.76 0 6.639-5.258 11.761-11.81 11.761-6.552 0-11.766-5.122-11.766-11.76s5.214-11.76 11.766-11.76zm47.896 0c3.61 0 6.73 1.649 8.468 4.722l-4.902 2.673c-.669-1.425-1.917-2.272-3.566-2.272-1.426 0-2.585.624-2.585 1.826 0 3.297 11.499 1.248 11.499 9.445 0 4.81-4.19 7.127-8.959 7.127-4.456 0-7.755-1.871-9.36-5.3l4.993-2.807c.624 1.826 2.14 2.895 4.367 2.895 1.828 0 3.076-.623 3.076-1.915 0-3.252-11.5-1.47-11.5-9.311 0-4.543 3.878-7.082 8.469-7.082zM21.935 0v21.474c0 1.446-.222 2.744-.63 3.896a9.017 9.017 0 01-3.561 4.569c-.005.009-.01.014-.015.014-1.791 1.36-4.422 1.839-6.384 1.839-5.121 0-9.425-2.24-10.768-6.545C.168 23.937 0 22.294 0 19.846l6.227.007c-.038 2.55.292 4.46 2.214 5.552 1.738.987 5.508.931 6.816-1.876.767-1.648.571-4.385.571-6.208V0h6.107zm85.327.193c8.602 0 15.02 6.815 15.02 15.592 0 8.776-6.418 15.591-15.02 15.591h-12.39V.193h12.39zm30.086 0c5.26 0 9.494 3.563 9.494 8.775 0 2.673-1.115 4.767-2.942 6.237 2.495 1.425 4.1 3.876 4.1 7.128 0 5.345-4.323 9.043-9.716 9.043h-13.237V.193h12.301zM61.085 13.958c-3.52 0-6.15 2.54-6.15 6.281 0 3.742 2.63 6.282 6.15 6.282 3.566 0 6.195-2.54 6.195-6.282s-2.629-6.28-6.195-6.28zm-25.61-.067c-3.388 0-6.017 2.54-6.017 6.148 0 3.608 2.63 6.147 6.017 6.147 3.431 0 6.061-2.539 6.061-6.147s-2.63-6.148-6.061-6.148zm102.81 4.388h-7.087v7.35h7.086c2.095 0 3.61-1.559 3.61-3.697 0-2.094-1.515-3.653-3.61-3.653zM107.261 6.073h-6.24v19.423h6.24c5.393 0 9.136-3.965 9.136-9.711 0-5.747-3.743-9.712-9.136-9.712zm30.086-.133h-6.15v6.86h6.15c1.917 0 3.343-1.47 3.343-3.43 0-1.96-1.382-3.43-3.343-3.43z" fill="#171A17" fill-rule="nonzero">
#       </path>
#      </svg>
#     </a>
#    </div>
#    <div class="header-right-column">
#     <a class="header-link heading-xsmall resume-link -desktop-only" data-ga-label="serp" data-ga-tracking-func="UploadResume.click" href="https://apply-sg.jobsdb.com/resume_upload/new?cc=SG" target="_blank">
#      Upload resume
#     </a>
#     <a class="header-link heading-xsmall log-in-link">
#      Log in
#     </a>
#     <a class="header-link heading-xsmall log-in-widget-link -desktop-only" href="javascript:void(0);">
#      Log in
#     </a>
#     <noscript data-auth-uri="/google_one_tap_sessions" data-client-id="885858900459-el0vajqnjmuflnht5k6lf37at5k8ficj.apps.googleusercontent.com" data-cookie-domain="sg.jobsdb.com" data-google-one-tap-sign-in="true">
#     </noscript>
#     <div class="login-widget closed">
#      <span class="login-widget-arrow" data-js-arrow="">
#      </span>
#      <div class="tabs-container login-form-tabs">
#       <a class="tab active" href="javascript:void(0);">
#        Job seeker
#       </a>
#       <a class="tab employer-link" data-bot-request="true" data-utm-campaign="header_link" data-utm-content="header_link" data-utm-medium="referral" data-utm-source="jora" href="https://employer-sg.jobsdb.com/sg/login" target="_blank">
#        Employer
#       </a>
#      </div>
#      <div class="login-container">
#       <div class="login-form authentication-form">
#        <form accept-charset="UTF-8" action="/users/sign_in" class="new_user" id="login_widget_new_user" method="post">
#         <input name="utf8" type="hidden" value="✓"/>
#         <input name="authenticity_token" type="hidden" value="sytosjJHgWjPicBmqSqc5K0dJ7yUeu9PZTif8LlGfUQja9sD6luJk3CZuipI66UtUzl6VHsyM4ZndTskTT5iJA=="/>
#         <div class="input-field email-input">
#          <label for="login_widget_user_email">
#           Email
#          </label>
#          <input icon="email" icon-position="right" id="login_widget_user_email" name="user[email]" placeholder="Enter your email" required="required" type="email"/>
#         </div>
#         <div class="input-field password-input">
#          <label for="login_widget_user_password">
#           Password
#          </label>
#          <input icon="password" icon-position="right" id="login_widget_user_password" name="user[password]" placeholder="Enter password" type="password"/>
#         </div>
#         <input class="button primary" data-disable-with="Log in" data-gtm="start-auth" name="commit" type="submit" value="Log in"/>
#         <a class="button secondary" href="/users/password/new">
#          Forgot your password?
#         </a>
#        </form>
#       </div>
#       <div class="privacy-statement heading-xxsmall">
#        By logging into your account, you agree to Jora's
#        <a href="/cms/terms-of-service">
#         Terms of Service
#        </a>
#        and
#        <a href="/cms/privacy">
#         Privacy Statement
#        </a>
#        .
#       </div>
#       <div class="create-account-prompt">
#        Don’t have a Jora account?
#       </div>
#       <div class="social-login-container">
#        <a class="jora-sign-up" data-gtm="start-auth" href="/users/sign_up" rel="nofollow">
#         <svg height="48" viewbox="0 0 48 48" width="48" xmlns="http://www.w3.org/2000/svg">
#          <g fill="none" fill-rule="evenodd">
#           <circle cx="24" cy="24" fill="#000" r="24">
#           </circle>
#           <path d="M19.113 34.02c-.264 0-.99.33-.99.99 0 .66.726.99.99.99h10.145c.274 0 .99-.33.99-.99 0-.66-.716-.99-.99-.99H19.113z" fill="#338722" fill-rule="nonzero">
#           </path>
#           <path d="M30.35 12.002h-1.921c-.53-.024-.982.148-1.356.515-.562.551-.745.862-.745 1.639v12.532c-.18 1.365-.959 2.047-2.337 2.047-1.378 0-2.12-.682-2.224-2.047v-2.454H18v2.849c0 1.2.045 4.846 5.991 4.707 5.946-.14 6.359-3.483 6.359-4.707v-15.08z" fill="#FFF" fill-rule="nonzero">
#           </path>
#          </g>
#         </svg>
#         <div class="heading-xsmall social-login-text">
#          Create account as a job seeker
#         </div>
#        </a>
#        <a class="facebook-login" data-gtm="start-auth" data-method="post" href="/users/auth/facebook" rel="nofollow">
#         <svg height="48" viewbox="0 0 48 48" width="48" xmlns="http://www.w3.org/2000/svg">
#          <path d="M24 0c13.255 0 24 10.745 24 24S37.255 48 24 48 0 37.255 0 24 10.745 0 24 0zm3.42 12c-3.407 0-5.634 2.064-5.634 5.802v3.285H18v4.311h3.786v10.42c.76.12 1.538.182 2.33.182.793 0 1.571-.062 2.33-.181v-10.42h3.475l.662-4.312h-4.136V18.29c0-1.18.577-2.329 2.43-2.329h1.88v-3.67S29.051 12 27.42 12z" fill="#3B5998" fill-rule="evenodd">
#          </path>
#         </svg>
#         <div class="heading-xsmall social-login-text">
#          Sign in with Facebook
#         </div>
#        </a>
#        <a data-client-id="com.jora.JobsDB.service" data-gtm="start-auth" data-redirect-uri="https://sg.jobsdb.com/sign_in_with_apple_sessions" data-sign-in-with-apple="true" href="#" rel="nofollow">
#         <svg height="48" viewbox="0 0 48 48" width="48" xmlns="http://www.w3.org/2000/svg">
#          <g fill="none" fill-rule="evenodd">
#           <g fill-rule="nonzero">
#            <g transform="translate(-170 -469) translate(170 469)">
#             <rect fill="#000" height="48" rx="24" width="48">
#             </rect>
#             <path d="M24.223 17.385c.832 0 1.875-.58 2.496-1.353.562-.7.972-1.68.972-2.658 0-.132-.011-.265-.035-.374-.926.036-2.039.64-2.707 1.45-.527.615-1.008 1.582-1.008 2.572 0 .145.024.29.036.338.058.013.152.025.246.025zM21.293 32c1.137 0 1.64-.785 3.059-.785 1.441 0 1.757.76 3.023.76 1.242 0 2.074-1.183 2.86-2.342.878-1.33 1.242-2.634 1.265-2.694-.082-.024-2.46-1.027-2.46-3.841 0-2.44 1.874-3.54 1.98-3.624-1.243-1.836-3.13-1.884-3.645-1.884-1.395 0-2.531.87-3.246.87-.774 0-1.793-.822-3-.822-2.297 0-4.629 1.957-4.629 5.653 0 2.295.867 4.723 1.934 6.293.914 1.329 1.71 2.416 2.859 2.416z" fill="#FFF">
#             </path>
#            </g>
#           </g>
#          </g>
#         </svg>
#         <div class="heading-xsmall social-login-text">
#          Sign in with Apple
#         </div>
#        </a>
#        <a class="google-login" data-gtm="start-auth" data-method="post" href="/users/auth/google_oauth2" rel="nofollow">
#         <svg height="48" viewbox="0 0 48 48" width="48" xmlns="http://www.w3.org/2000/svg">
#          <g fill="none" fill-rule="evenodd">
#           <circle cx="24" cy="24" fill="#F7F7F7" r="24">
#           </circle>
#           <g>
#            <path d="M17.64 9.205c0-.639-.057-1.252-.164-1.841H9v3.481h4.844c-.209 1.125-.843 2.078-1.796 2.716v2.259h2.908c1.702-1.567 2.684-3.875 2.684-6.615z" fill="#4285F4" transform="translate(15 15)">
#            </path>
#            <path d="M9 18c2.43 0 4.467-.806 5.956-2.18l-2.908-2.259c-.806.54-1.837.86-3.048.86-2.344 0-4.328-1.584-5.036-3.711H.957v2.332C2.438 15.983 5.482 18 9 18z" fill="#34A853" transform="translate(15 15)">
#            </path>
#            <path d="M3.964 10.71c-.18-.54-.282-1.117-.282-1.71s.102-1.17.282-1.71V4.958H.957C.347 6.173 0 7.548 0 9s.348 2.827.957 4.042l3.007-2.332z" fill="#FBBC05" transform="translate(15 15)">
#            </path>
#            <path d="M9 3.58c1.321 0 2.508.454 3.44 1.345l2.582-2.58C13.463.891 11.426 0 9 0 5.482 0 2.438 2.017.957 4.958L3.964 7.29C4.672 5.163 6.656 3.58 9 3.58z" fill="#EA4335" transform="translate(15 15)">
#            </path>
#           </g>
#          </g>
#         </svg>
#         <div class="heading-xsmall social-login-text">
#          Sign in with Google
#         </div>
#        </a>
#       </div>
#      </div>
#     </div>
#     <span class="separator">
#     </span>
#     <a class="header-link heading-xsmall post-job-link employer-link -desktop-only" data-bot-request="true" data-utm-campaign="header_link_post_job" data-utm-content="header_link_post_job" data-utm-medium="referral" data-utm-source="jora" href="https://employer-sg.jobsdb.com/sg/post-job" target="_blank">
#      Post a job
#     </a>
#     <a class="header-link heading-xsmall menu-link" icon="mobile-menu" icon-position="right">
#      <span>
#       Menu
#      </span>
#     </a>
#    </div>
#   </header>
#   <div class="mobile-dropdown-container closed">
#    <div class="login-form-content">
#     <div class="tabs-container login-form-tabs">
#      <a class="tab active" href="javascript:void(0);">
#       Job seeker
#      </a>
#      <a class="tab employer-link" data-bot-request="true" data-utm-campaign="header_link" data-utm-content="header_link" data-utm-medium="referral" data-utm-source="jora" href="https://employer-sg.jobsdb.com/sg/login" target="_blank">
#       Employer
#      </a>
#     </div>
#     <div class="login-container">
#      <div class="login-form authentication-form">
#       <form accept-charset="UTF-8" action="/users/sign_in" class="new_user" id="mobile_drowpdown_new_user" method="post">
#        <input name="utf8" type="hidden" value="✓"/>
#        <input name="authenticity_token" type="hidden" value="vvVnMH5YjW5K7AGoMRT3rznH/M+FnNS3J0q99hYBdOEutdSBpkSFlfX8e+TQ1c5mx+OhJ2rUCH4lBxki4nlrgQ=="/>
#        <div class="input-field email-input">
#         <label for="mobile_drowpdown_user_email">
#          Email
#         </label>
#         <input icon="email" icon-position="right" id="mobile_drowpdown_user_email" name="user[email]" placeholder="Enter your email" required="required" type="email"/>
#        </div>
#        <div class="input-field password-input">
#         <label for="mobile_drowpdown_user_password">
#          Password
#         </label>
#         <input icon="password" icon-position="right" id="mobile_drowpdown_user_password" name="user[password]" placeholder="Enter password" type="password"/>
#        </div>
#        <input class="button primary" data-disable-with="Log in" data-gtm="start-auth" name="commit" type="submit" value="Log in"/>
#        <a class="button secondary" href="/users/password/new">
#         Forgot your password?
#        </a>
#       </form>
#      </div>
#      <div class="privacy-statement heading-xxsmall">
#       By logging into your account, you agree to Jora's
#       <a href="/cms/terms-of-service">
#        Terms of Service
#       </a>
#       and
#       <a href="/cms/privacy">
#        Privacy Statement
#       </a>
#       .
#      </div>
#      <div class="create-account-prompt">
#       Don’t have a Jora account?
#      </div>
#      <div class="social-login-container">
#       <a class="jora-sign-up" data-gtm="start-auth" href="/users/sign_up" rel="nofollow">
#        <svg height="48" viewbox="0 0 48 48" width="48" xmlns="http://www.w3.org/2000/svg">
#         <g fill="none" fill-rule="evenodd">
#          <circle cx="24" cy="24" fill="#000" r="24">
#          </circle>
#          <path d="M19.113 34.02c-.264 0-.99.33-.99.99 0 .66.726.99.99.99h10.145c.274 0 .99-.33.99-.99 0-.66-.716-.99-.99-.99H19.113z" fill="#338722" fill-rule="nonzero">
#          </path>
#          <path d="M30.35 12.002h-1.921c-.53-.024-.982.148-1.356.515-.562.551-.745.862-.745 1.639v12.532c-.18 1.365-.959 2.047-2.337 2.047-1.378 0-2.12-.682-2.224-2.047v-2.454H18v2.849c0 1.2.045 4.846 5.991 4.707 5.946-.14 6.359-3.483 6.359-4.707v-15.08z" fill="#FFF" fill-rule="nonzero">
#          </path>
#         </g>
#        </svg>
#        <div class="heading-xsmall social-login-text">
#         Create account as a job seeker
#        </div>
#       </a>
#       <a class="facebook-login" data-gtm="start-auth" data-method="post" href="/users/auth/facebook" rel="nofollow">
#        <svg height="48" viewbox="0 0 48 48" width="48" xmlns="http://www.w3.org/2000/svg">
#         <path d="M24 0c13.255 0 24 10.745 24 24S37.255 48 24 48 0 37.255 0 24 10.745 0 24 0zm3.42 12c-3.407 0-5.634 2.064-5.634 5.802v3.285H18v4.311h3.786v10.42c.76.12 1.538.182 2.33.182.793 0 1.571-.062 2.33-.181v-10.42h3.475l.662-4.312h-4.136V18.29c0-1.18.577-2.329 2.43-2.329h1.88v-3.67S29.051 12 27.42 12z" fill="#3B5998" fill-rule="evenodd">
#         </path>
#        </svg>
#        <div class="heading-xsmall social-login-text">
#         Sign in with Facebook
#        </div>
#       </a>
#       <a data-client-id="com.jora.JobsDB.service" data-gtm="start-auth" data-redirect-uri="https://sg.jobsdb.com/sign_in_with_apple_sessions" data-sign-in-with-apple="true" href="#" rel="nofollow">
#        <svg height="48" viewbox="0 0 48 48" width="48" xmlns="http://www.w3.org/2000/svg">
#         <g fill="none" fill-rule="evenodd">
#          <g fill-rule="nonzero">
#           <g transform="translate(-170 -469) translate(170 469)">
#            <rect fill="#000" height="48" rx="24" width="48">
#            </rect>
#            <path d="M24.223 17.385c.832 0 1.875-.58 2.496-1.353.562-.7.972-1.68.972-2.658 0-.132-.011-.265-.035-.374-.926.036-2.039.64-2.707 1.45-.527.615-1.008 1.582-1.008 2.572 0 .145.024.29.036.338.058.013.152.025.246.025zM21.293 32c1.137 0 1.64-.785 3.059-.785 1.441 0 1.757.76 3.023.76 1.242 0 2.074-1.183 2.86-2.342.878-1.33 1.242-2.634 1.265-2.694-.082-.024-2.46-1.027-2.46-3.841 0-2.44 1.874-3.54 1.98-3.624-1.243-1.836-3.13-1.884-3.645-1.884-1.395 0-2.531.87-3.246.87-.774 0-1.793-.822-3-.822-2.297 0-4.629 1.957-4.629 5.653 0 2.295.867 4.723 1.934 6.293.914 1.329 1.71 2.416 2.859 2.416z" fill="#FFF">
#            </path>
#           </g>
#          </g>
#         </g>
#        </svg>
#        <div class="heading-xsmall social-login-text">
#         Sign in with Apple
#        </div>
#       </a>
#       <a class="google-login" data-gtm="start-auth" data-method="post" href="/users/auth/google_oauth2" rel="nofollow">
#        <svg height="48" viewbox="0 0 48 48" width="48" xmlns="http://www.w3.org/2000/svg">
#         <g fill="none" fill-rule="evenodd">
#          <circle cx="24" cy="24" fill="#F7F7F7" r="24">
#          </circle>
#          <g>
#           <path d="M17.64 9.205c0-.639-.057-1.252-.164-1.841H9v3.481h4.844c-.209 1.125-.843 2.078-1.796 2.716v2.259h2.908c1.702-1.567 2.684-3.875 2.684-6.615z" fill="#4285F4" transform="translate(15 15)">
#           </path>
#           <path d="M9 18c2.43 0 4.467-.806 5.956-2.18l-2.908-2.259c-.806.54-1.837.86-3.048.86-2.344 0-4.328-1.584-5.036-3.711H.957v2.332C2.438 15.983 5.482 18 9 18z" fill="#34A853" transform="translate(15 15)">
#           </path>
#           <path d="M3.964 10.71c-.18-.54-.282-1.117-.282-1.71s.102-1.17.282-1.71V4.958H.957C.347 6.173 0 7.548 0 9s.348 2.827.957 4.042l3.007-2.332z" fill="#FBBC05" transform="translate(15 15)">
#           </path>
#           <path d="M9 3.58c1.321 0 2.508.454 3.44 1.345l2.582-2.58C13.463.891 11.426 0 9 0 5.482 0 2.438 2.017.957 4.958L3.964 7.29C4.672 5.163 6.656 3.58 9 3.58z" fill="#EA4335" transform="translate(15 15)">
#           </path>
#          </g>
#         </g>
#        </svg>
#        <div class="heading-xsmall social-login-text">
#         Sign in with Google
#        </div>
#       </a>
#      </div>
#     </div>
#    </div>
#    <div class="mobile-menu-content">
#     <div class="mobile-menu-section jobseeker-menu-section">
#      <div class="mobile-menu-title">
#       Job seeker
#      </div>
#      <a class="mobile-menu-link -link-highlight heading-xsmall jobseeker-sign-up-link" data-gtm="start-auth" href="/users/sign_up" rel="nofollow">
#       Sign up
#      </a>
#      <a class="mobile-menu-link -link-highlight heading-xsmall" data-ga-label="serp" data-ga-tracking-func="UploadResume.click" href="https://apply-sg.jobsdb.com/resume_upload/new?cc=SG" target="_blank">
#       Upload resume
#      </a>
#     </div>
#     <div class="mobile-menu-section employer-menu-section">
#      <div class="mobile-menu-title">
#       Employer
#      </div>
#      <a class="mobile-menu-link -link-highlight heading-xsmall employer-sign-up-link employer-link" data-bot-request="true" data-utm-campaign="header_link_signup" data-utm-content="header_link_signup" data-utm-medium="referral" data-utm-source="jora" href="https://employer-sg.jobsdb.com/sg/" target="_blank">
#       Sign up
#      </a>
#      <a class="mobile-menu-link -link-highlight heading-xsmall post-job-link employer-link" data-bot-request="true" data-utm-campaign="header_link_post_job" data-utm-content="header_link_post_job" data-utm-medium="referral" data-utm-source="jora" href="https://employer-sg.jobsdb.com/sg/post-job" target="_blank">
#       Post a job
#      </a>
#     </div>
#     <div class="mobile-app-stores">
#      <a class="app-store-link" href="https://jobsdb.app.link/jobsdbapp_menu">
#       <img alt="Link to App Store" loading="lazy" src="https://jora-assets.jora.com/assets/app-store-logos/app-store-en-2c4d037cb4b180f838fbbb32e0c39fca95a43952c6ce6c59ad60cf29045ce9f1.png"/>
#      </a>
#      <a class="play-store-link" href="https://jobsdb.app.link/jobsdbapp_menu">
#       <img alt="Link to Play Store" loading="lazy" src="https://jora-assets.jora.com/assets/app-store-logos/play-store-en-b32a0f082006882bc619c9564da4ee3706f933f34b26f59c05325d51e3d3289f.png"/>
#      </a>
#     </div>
#    </div>
#   </div>
#   <div class="content-container -wide">
#    <form action="/j" class="search-form desktop-top-search-form -desktop-only" data-ga-label="desktop_top" method="get">
#     <input name="sp" type="hidden" value="search"/>
#     <div class="keyword-input search-input-field input-field -visible-label autocomplete-container">
#      <label for="desktop-top-q">
#       What
#      </label>
#      <input data-url="/rpc/search_keywords/suggest" icon="search" icon-position="right" id="desktop-top-q" maxlength="512" name="q" placeholder="Job title, company, keyword" type="search" value=""/>
#     </div>
#     <div class="location-input search-input-field input-field -visible-label autocomplete-container">
#      <label for="desktop-top-l">
#       Where
#      </label>
#      <input data-url="/rpc/search_locations/suggest" icon="location" icon-position="right" id="desktop-top-l" maxlength="64" name="l" placeholder="City, district, state" type="search" value="Singapore"/>
#     </div>
#     <input class="button primary search-jobs-button" type="submit" value="Search jobs"/>
#    </form>
#   </div>
#   <div class="search-results-page content-container -wide grid-container -three-columns">
#    <div class="search-bar-container">
#     <h1 class="search-bar-title heading-small -no-margin-bottom open-modal" data-focus="input#search-modal-q" data-lock-scroll="true" data-open="search-modal">
#      jobs in
#      <strong>
#       Singapore
#      </strong>
#     </h1>
#     <button class="search-bar-filter-button quinary open-modal" data-ga-tracking-func="Filters.expand" data-lock-scroll="true" data-open="refine-search-modal" data-scroll-top="true" icon="filter">
#      Filter
#     </button>
#     <div class="closed" id="search-modal">
#      <button class="quinary close-modal" data-close="search-modal" data-lock-release="true" icon="chevron-left">
#       Back
#      </button>
#      <form action="/j" class="search-form" data-ga-label="search_modal" method="get">
#       <input name="sp" type="hidden" value="search"/>
#       <div class="keyword-input search-input-field input-field -visible-label autocomplete-container">
#        <label for="search-modal-q">
#         What
#        </label>
#        <input data-url="/rpc/search_keywords/suggest" icon="search" icon-position="right" id="search-modal-q" maxlength="512" name="q" placeholder="Job title, company, keyword" type="search" value=""/>
#       </div>
#       <div class="location-input search-input-field input-field -visible-label autocomplete-container">
#        <label for="search-modal-l">
#         Where
#        </label>
#        <input data-url="/rpc/search_locations/suggest" icon="location" icon-position="right" id="search-modal-l" maxlength="64" name="l" placeholder="City, district, state" type="search" value="Singapore"/>
#       </div>
#       <input class="button primary search-jobs-button" type="submit" value="Search jobs"/>
#      </form>
#     </div>
#     <div class="closed" id="refine-search-modal">
#      <div class="refine-search-title-bar">
#       <button class="quinary close-modal" data-close="refine-search-modal" data-ga-tracking-func="Filters.collapse" data-lock-release="true" data-reset-form="" icon="chevron-left">
#        Back
#       </button>
#       <h2 class="heading-large page-heading -no-margin-bottom">
#        Refine
#       </h2>
#       <button class="quaternary refine-search-clear-button" data-reset-form="">
#        Clear
#       </button>
#      </div>
#      <form class="refine-search-form refine-search-container">
#       <input id="source_page" name="sp" type="hidden" value="facet"/>
#       <input id="keyword" name="q" type="hidden" value=""/>
#       <input id="location" name="l" type="hidden" value="Singapore"/>
#       <fieldset class="refine-search-facet">
#        <h4 class="heading-medium facet-title -no-margin-bottom">
#         Sort by
#        </h4>
#        <input checked="checked" class="facet-input" id="st-relevance" name="st" type="radio" value=""/>
#        <label class="button tertiary facet-button" for="st-relevance">
#         Relevance
#        </label>
#        <input class="facet-input" id="st-date" name="st" type="radio" value="date"/>
#        <label class="button tertiary facet-button" for="st-date">
#         Date
#        </label>
#       </fieldset>
#       <fieldset class="refine-search-facet">
#        <h4 class="heading-medium facet-title -no-margin-bottom">
#         Job type
#        </h4>
#        <input checked="checked" class="facet-input" id="jt-all" name="jt" type="radio" value=""/>
#        <label class="button tertiary facet-button" for="jt-all">
#         Any job type
#        </label>
#        <input class="facet-input" id="jt-3" name="jt" type="radio" value="3"/>
#        <label class="button tertiary facet-button" for="jt-3">
#         Full time
#        </label>
#        <input class="facet-input" id="jt-6" name="jt" type="radio" value="6"/>
#        <label class="button tertiary facet-button" for="jt-6">
#         Permanent
#        </label>
#        <input class="facet-input" id="jt-4" name="jt" type="radio" value="4"/>
#        <label class="button tertiary facet-button" for="jt-4">
#         Contract
#        </label>
#        <input class="facet-input" id="jt-1" name="jt" type="radio" value="1"/>
#        <label class="button tertiary facet-button" for="jt-1">
#         Part time
#        </label>
#        <input class="facet-input" id="jt-2" name="jt" type="radio" value="2"/>
#        <label class="button tertiary facet-button" for="jt-2">
#         Casual/Temporary
#        </label>
#       </fieldset>
#       <fieldset class="refine-search-facet">
#        <h4 class="heading-medium facet-title -no-margin-bottom">
#         Listed date
#        </h4>
#        <input checked="checked" class="facet-input" id="a-all" name="a" type="radio" value=""/>
#        <label class="button tertiary facet-button" for="a-all">
#         Any time
#        </label>
#        <input class="facet-input" id="a-24h" name="a" type="radio" value="24h"/>
#        <label class="button tertiary facet-button" for="a-24h">
#         Last 24 hours
#        </label>
#        <input class="facet-input" id="a-7d" name="a" type="radio" value="7d"/>
#        <label class="button tertiary facet-button" for="a-7d">
#         Last 7 days
#        </label>
#        <input class="facet-input" id="a-14d" name="a" type="radio" value="14d"/>
#        <label class="button tertiary facet-button" for="a-14d">
#         Last 14 days
#        </label>
#        <input class="facet-input" id="a-30d" name="a" type="radio" value="30d"/>
#        <label class="button tertiary facet-button" for="a-30d">
#         Last 30 days
#        </label>
#       </fieldset>
#       <fieldset class="refine-search-facet">
#        <div class="section-header">
#         <h4 class="heading-medium facet-title -no-margin-bottom">
#          Distance
#         </h4>
#         <div class="current-radius">
#          10km
#         </div>
#        </div>
#        <input disabled="true" id="distance-slider-input" list="distance-datalist" name="r_input" output="user-selected-slider-value" type="range" value="10"/>
#        <input id="user-selected-slider-value" name="r" type="hidden" value=""/>
#        <datalist id="distance-datalist">
#         <option value="0">
#         </option>
#         <option value="5">
#         </option>
#         <option value="10">
#         </option>
#         <option value="25">
#         </option>
#         <option value="50">
#         </option>
#         <option value="100">
#         </option>
#        </datalist>
#        <div id="distance-slider-ui">
#         <div class="filled">
#         </div>
#         <div class="step-marker-container">
#          <div class="step-marker">
#          </div>
#          <div class="step-marker">
#          </div>
#          <div class="step-marker">
#          </div>
#          <div class="step-marker">
#          </div>
#          <div class="step-marker">
#          </div>
#          <div class="step-marker">
#          </div>
#         </div>
#         <div class="dial">
#         </div>
#        </div>
#       </fieldset>
#       <div class="full-height-container" data-fix-ios-viewport-height="true">
#        <div class="action-container">
#         <div class="safe">
#          <button class="primary" method="get" type="submit">
#           Refine search
#          </button>
#         </div>
#        </div>
#       </div>
#      </form>
#     </div>
#    </div>
#    <div class="serp-left-pane grid-left-pane">
#     <div class="desktop-filter-heading heading-medium" icon="filter">
#      Filter
#     </div>
#     <div class="refine-search-container" id="desktop-refine-search">
#      <div class="refine-search-facet">
#       <h4 class="heading-medium facet-title -no-margin-bottom">
#        Sort by
#       </h4>
#       <div class="button tertiary facet-button selected">
#        Relevance
#       </div>
#       <button class="tertiary facet-button" data-href="/j?l=Singapore&amp;q=&amp;sp=homepage&amp;st=date" name="button" type="submit">
#        Date
#       </button>
#      </div>
#      <div class="refine-search-facet">
#       <h4 class="heading-medium facet-title -no-margin-bottom">
#        Job type
#       </h4>
#       <div class="button tertiary facet-button selected">
#        Any job type
#       </div>
#       <button class="tertiary facet-button" data-href="/j?jt=3&amp;l=Singapore&amp;q=&amp;sp=facet_job_type" name="button" type="submit">
#        Full time
#       </button>
#       <button class="tertiary facet-button" data-href="/j?jt=6&amp;l=Singapore&amp;q=&amp;sp=facet_job_type" name="button" type="submit">
#        Permanent
#       </button>
#       <button class="tertiary facet-button" data-href="/j?jt=4&amp;l=Singapore&amp;q=&amp;sp=facet_job_type" name="button" type="submit">
#        Contract
#       </button>
#       <button class="tertiary facet-button" data-href="/j?jt=1&amp;l=Singapore&amp;q=&amp;sp=facet_job_type" name="button" type="submit">
#        Part time
#       </button>
#       <button class="tertiary facet-button" data-href="/j?jt=2&amp;l=Singapore&amp;q=&amp;sp=facet_job_type" name="button" type="submit">
#        Casual/Temporary
#       </button>
#      </div>
#      <div class="refine-search-facet">
#       <h4 class="heading-medium facet-title -no-margin-bottom">
#        Listed date
#       </h4>
#       <div class="button tertiary facet-button selected">
#        Any time
#       </div>
#       <button class="tertiary facet-button" data-href="/j?a=24h&amp;l=Singapore&amp;q=&amp;sp=facet_listed_date" name="button" type="submit">
#        Last 24 hours
#       </button>
#       <button class="tertiary facet-button" data-href="/j?a=7d&amp;l=Singapore&amp;q=&amp;sp=facet_listed_date" name="button" type="submit">
#        Last 7 days
#       </button>
#       <button class="tertiary facet-button" data-href="/j?a=14d&amp;l=Singapore&amp;q=&amp;sp=facet_listed_date" name="button" type="submit">
#        Last 14 days
#       </button>
#       <button class="tertiary facet-button" data-href="/j?a=30d&amp;l=Singapore&amp;q=&amp;sp=facet_listed_date" name="button" type="submit">
#        Last 30 days
#       </button>
#      </div>
#      <div class="refine-search-facet">
#       <h4 class="heading-medium facet-title -no-margin-bottom">
#        Distance
#       </h4>
#       <select id="location-radius-list" name="location-radius-list">
#        <option value="0">
#         Exact location
#        </option>
#        <option value="5">
#         Within 5km
#        </option>
#        <option selected="selected" value="10">
#         Within 10km
#        </option>
#        <option value="25">
#         Within 25km
#        </option>
#        <option value="50">
#         Within 50km
#        </option>
#        <option value="100">
#         Within 100km
#        </option>
#       </select>
#      </div>
#     </div>
#    </div>
#    <div class="serp-content grid-content">
#     <div class="serp-content-top-container">
#      <div class="search-results-count">
#       <strong>
#        173,199
#       </strong>
#       jobs
#       <span class="divider">
#        –
#       </span>
#       Page
#       <strong>
#        1
#       </strong>
#       of
#       <strong>
#        50
#       </strong>
#      </div>
#     </div>
#     <script>
#      (function(G,o,O,g,L,e){G[g]=G[g]||function(){(G[g]['q']=G[g]['q']||[]).push(
# arguments)},G[g]['t']=1*new Date;})(window,document,'script','_googCsa');
#     </script>
#     <div class="jobresults" id="jobresults">
#      <div class="jora-sponsored-results">
#       <div class="job-container result sponsored-job sponsored-top" data-impression-job-type="sponsored" data-impression-sp="sserp_top" data-job-item="" id="r_a3e0a84cbf477cfc3e76c2e2d25d1aa2">
#        <a class="job-item" data-ga-label="Neuvoo SG" data-gtm="view-job" data-rank="1" data-rd="LS0tCjpzcjogMQo6c3A6IHNzZXJwX3RvcAo6c3BvbnNvcmVkOiB0cnVlCjp0azogbHZLSXFBbm15UTJzM2pzMzVSSGktYlY4amNveG1UWXZsVWhOWG81bWEK" href="/job/rd/a3e0a84cbf477cfc3e76c2e2d25d1aa2?sp=sserp_top&amp;sponsored=true&amp;sr=1&amp;tk=lvKIqAnmyQ2s3js35RHi-bV8jcoxmTYvlUhNXo5ma" rel="nofollow noopener" target="_blank" title="PRIME MOVER DRIVER | $2000 BONUS">
#         <div class="job-item-top-container">
#          <h3 class="job-title heading-large -no-margin-bottom -one-line">
#           PRIME MOVER DRIVER | $2000 BONUS
#          </h3>
#         </div>
#         <div class="company-location-container heading-small">
#          <span class="job-company">
#           Call Lade Enterprises Pte Ltd
#          </span>
#          <span class="divider">
#           –
#          </span>
#          <span class="job-location">
#           Singapore
#          </span>
#         </div>
#         <div class="job-salary-badge badge">
#          $3,000 - $3,700 per month
#         </div>
#         <div class="job-abstract">
#          We are a well-established logistics company located in Pasir Panjang. We aim to maintain a conducive working environment where employees can find...
#         </div>
#         <div class="job-meta">
#          <div class="cite">
#           <span class="sponsor-label">
#            Ad
#           </span>
#           <span class="sponsor-name heading-xsmall">
#            Neuvoo SG
#           </span>
#          </div>
#         </div>
#        </a>
#       </div>
#       <div class="job-container result sponsored-job sponsored-top" data-impression-job-type="sponsored" data-impression-sp="sserp_top" data-job-item="" id="r_c0b758ce398ff47fe49049728441fdaf">
#        <a class="job-item" data-ga-label="eFinancialCareers SG" data-gtm="view-job" data-rank="2" data-rd="LS0tCjpzcjogMgo6c3A6IHNzZXJwX3RvcAo6c3BvbnNvcmVkOiB0cnVlCjp0azogbHZLSXFBbm15UTJzM2pzMzVSSGktYlY4amNveG1UWXZsVWhOWG81bWEK" href="/job/rd/c0b758ce398ff47fe49049728441fdaf?sp=sserp_top&amp;sponsored=true&amp;sr=2&amp;tk=lvKIqAnmyQ2s3js35RHi-bV8jcoxmTYvlUhNXo5ma" rel="nofollow noopener" target="_blank" title="Power Market Analyst (Renewable Energy, Carbon &amp; Climate change) - Singapore">
#         <div class="job-item-top-container">
#          <h3 class="job-title heading-large -no-margin-bottom -one-line">
#           Power Market Analyst (Renewable Energy, Carbon &amp; Climate change) - Singapore
#          </h3>
#         </div>
#         <div class="company-location-container heading-small">
#          <span class="job-company">
#           Octavius Finance
#          </span>
#          <span class="divider">
#           –
#          </span>
#          <span class="job-location">
#           Singapore
#          </span>
#         </div>
#         <div class="job-abstract">
#          They are looking for someone with a passion for the energy sector and climate change who can produce detailed analysis of key economic and regulatory drivers...
#         </div>
#         <div class="job-meta">
#          <div class="cite">
#           <span class="sponsor-label">
#            Ad
#           </span>
#           <span class="sponsor-name heading-xsmall">
#            eFinancialCareers SG
#           </span>
#          </div>
#         </div>
#        </a>
#       </div>
#      </div>
#      <div class="job-container result organic-job" data-impression-job-type="organic" data-impression-sp="serp" data-job-item="" id="r_6e3efb580f97bd7252466c5e03990e87">
#       <a class="job-item" data-ga-label="jobsDB Singapore" data-gtm="view-job" data-rank="1" data-rd="LS0tCjpzcjogMQo6c3A6IHNlcnAKOnNwb25zb3JlZDogZmFsc2UKOnRrOiBsdktJcUFubXlRMnMzanMzNVJIaS1iVjhqY294bVRZdmxVaE5YbzVtYQo=" href="/job/Part-time-Office-Assistant-6e3efb580f97bd7252466c5e03990e87?from_url=https%3A%2F%2Fsg.jobsdb.com%2Fj%3Fsp%3Dhomepage%26q%3D%26l%3DSingapore&amp;sl=Singapore&amp;sol_srt=2e2c2e7a-24da-4904-9236-0c732793cbe1&amp;sp=serp&amp;sponsored=false&amp;sq=&amp;sr=1&amp;tk=lvKIqAnmyQ2s3js35RHi-bV8jcoxmTYvlUhNXo5ma" rel="nofollow noopener" target="_blank" title="PART-TIME OFFICE ASSISTANT (8-MONTH TEMPORARY JOB)">
#        <div class="job-item-top-container">
#         <h3 class="job-title heading-large -no-margin-bottom">
#          PART-TIME OFFICE ASSISTANT (8-MONTH TEMPORARY JOB)
#         </h3>
#         <span class="badge new-job-badge">
#          new
#         </span>
#        </div>
#        <div class="company-location-container heading-small">
#         <span class="job-company">
#          Sejong Korean Language School
#         </span>
#         <span class="divider">
#          –
#         </span>
#         <span class="job-location">
#          Downtown Core
#         </span>
#        </div>
#        <div class="quick-apply-badge badge -color-purple">
#         Quick apply
#        </div>
#        <div class="job-abstract">
#         Salary: $700.00 per month WORKING HOURS (2 DAYS PER WEEK, 8 HOURS PER DAY): Weekdays (Mondays to Thursdays): 2pm - 10pm Weekends (Saturdays &amp; Sundays): 10am...
#        </div>
#        <div class="job-item-bottom-container">
#         <span class="job-listed-date heading-xsmall">
#          1 day ago
#         </span>
#         <button class="tertiary save-job-button" data-disabled="" data-ga-label="serp" data-ga-tracking-func="SavingJob.clicked" data-job-id="6e3efb580f97bd7252466c5e03990e87" data-label-save="Save" data-label-saved="Saved" data-saved="false" data-tk="lvKIqAnmyQ2s3js35RHi-bV8jcoxmTYvlUhNXo5ma" icon="">
#          Save
#         </button>
#        </div>
#       </a>
#      </div>
#      <div class="job-container result organic-job" data-impression-job-type="organic" data-impression-sp="serp" data-job-item="" id="r_ed3c66b41627671f06fecee63f718797">
#       <a class="job-item" data-ga-label="jobsDB Singapore" data-gtm="view-job" data-rank="2" data-rd="LS0tCjpzcjogMgo6c3A6IHNlcnAKOnNwb25zb3JlZDogZmFsc2UKOnRrOiBsdktJcUFubXlRMnMzanMzNVJIaS1iVjhqY294bVRZdmxVaE5YbzVtYQo=" href="/job/Admin-Assistant-ed3c66b41627671f06fecee63f718797?from_url=https%3A%2F%2Fsg.jobsdb.com%2Fj%3Fsp%3Dhomepage%26q%3D%26l%3DSingapore&amp;sl=Singapore&amp;sol_srt=2e2c2e7a-24da-4904-9236-0c732793cbe1&amp;sp=serp&amp;sponsored=false&amp;sq=&amp;sr=2&amp;tk=lvKIqAnmyQ2s3js35RHi-bV8jcoxmTYvlUhNXo5ma" rel="nofollow noopener" target="_blank" title="Admin Assistant">
#        <div class="job-item-top-container">
#         <h3 class="job-title heading-large -no-margin-bottom">
#          Admin Assistant
#         </h3>
#         <span class="badge new-job-badge">
#          new
#         </span>
#        </div>
#        <div class="company-location-container heading-small">
#         <span class="job-company">
#          Maraicar Agency
#         </span>
#         <span class="divider">
#          –
#         </span>
#         <span class="job-location">
#          Geylang
#         </span>
#        </div>
#        <div class="quick-apply-badge badge -color-purple">
#         Quick apply
#        </div>
#        <div class="job-abstract">
#         Be able to organise/file documents based on the content of documents Be able to use Microsoft words, excel and PDF editor Be able to use Cloud Storage...
#        </div>
#        <div class="job-item-bottom-container">
#         <span class="job-listed-date heading-xsmall">
#          about 2 hours ago
#         </span>
#         <button class="tertiary save-job-button" data-disabled="" data-ga-label="serp" data-ga-tracking-func="SavingJob.clicked" data-job-id="ed3c66b41627671f06fecee63f718797" data-label-save="Save" data-label-saved="Saved" data-saved="false" data-tk="lvKIqAnmyQ2s3js35RHi-bV8jcoxmTYvlUhNXo5ma" icon="">
#          Save
#         </button>
#        </div>
#       </a>
#      </div>
#      <div class="job-container result organic-job" data-impression-job-type="organic" data-impression-sp="serp" data-job-item="" id="r_85564e30dff7630e27cdf81460eff1cc">
#       <a class="job-item" data-ga-label="jobsDB Singapore" data-gtm="view-job" data-rank="3" data-rd="LS0tCjpzcjogMwo6c3A6IHNlcnAKOnNwb25zb3JlZDogZmFsc2UKOnRrOiBsdktJcUFubXlRMnMzanMzNVJIaS1iVjhqY294bVRZdmxVaE5YbzVtYQo=" href="/job/Admin-Assistant-85564e30dff7630e27cdf81460eff1cc?from_url=https%3A%2F%2Fsg.jobsdb.com%2Fj%3Fsp%3Dhomepage%26q%3D%26l%3DSingapore&amp;sl=Singapore&amp;sol_srt=2e2c2e7a-24da-4904-9236-0c732793cbe1&amp;sp=serp&amp;sponsored=false&amp;sq=&amp;sr=3&amp;tk=lvKIqAnmyQ2s3js35RHi-bV8jcoxmTYvlUhNXo5ma" rel="nofollow noopener" target="_blank" title="Admin Assistant">
#        <div class="job-item-top-container">
#         <h3 class="job-title heading-large -no-margin-bottom">
#          Admin Assistant
#         </h3>
#         <span class="badge new-job-badge">
#          new
#         </span>
#        </div>
#        <div class="company-location-container heading-small">
#         <span class="job-company">
#          Weissach Motors Pte Ltd
#         </span>
#         <span class="divider">
#          –
#         </span>
#         <span class="job-location">
#          Bedok
#         </span>
#        </div>
#        <div class="quick-apply-badge badge -color-purple">
#         Quick apply
#        </div>
#        <div class="job-abstract">
#         Handling office tasks, such as filing, generating reports and presentations, setting up for meetings, and reordering supplies. Providing real-time scheduling...
#        </div>
#        <div class="job-item-bottom-container">
#         <span class="job-listed-date heading-xsmall">
#          1 day ago
#         </span>
#         <button class="tertiary save-job-button" data-disabled="" data-ga-label="serp" data-ga-tracking-func="SavingJob.clicked" data-job-id="85564e30dff7630e27cdf81460eff1cc" data-label-save="Save" data-label-saved="Saved" data-saved="false" data-tk="lvKIqAnmyQ2s3js35RHi-bV8jcoxmTYvlUhNXo5ma" icon="">
#          Save
#         </button>
#        </div>
#       </a>
#      </div>
#      <div class="job-container result organic-job" data-impression-job-type="organic" data-impression-sp="serp" data-job-item="" id="r_e0cb8f4ed4a4021c52f4ce372cd3fad8">
#       <a class="job-item" data-ga-label="jobsDB Singapore" data-gtm="view-job" data-rank="4" data-rd="LS0tCjpzcjogNAo6c3A6IHNlcnAKOnNwb25zb3JlZDogZmFsc2UKOnRrOiBsdktJcUFubXlRMnMzanMzNVJIaS1iVjhqY294bVRZdmxVaE5YbzVtYQo=" href="/job/Warehouse-Assistant-e0cb8f4ed4a4021c52f4ce372cd3fad8?from_url=https%3A%2F%2Fsg.jobsdb.com%2Fj%3Fsp%3Dhomepage%26q%3D%26l%3DSingapore&amp;sl=Singapore&amp;sol_srt=2e2c2e7a-24da-4904-9236-0c732793cbe1&amp;sp=serp&amp;sponsored=false&amp;sq=&amp;sr=4&amp;tk=lvKIqAnmyQ2s3js35RHi-bV8jcoxmTYvlUhNXo5ma" rel="nofollow noopener" target="_blank" title="Warehouse Assistant">
#        <div class="job-item-top-container">
#         <h3 class="job-title heading-large -no-margin-bottom">
#          Warehouse Assistant
#         </h3>
#         <span class="badge new-job-badge">
#          new
#         </span>
#        </div>
#        <div class="company-location-container heading-small">
#         <span class="job-company">
#          Thinktrek Logistics Pte Ltd
#         </span>
#         <span class="divider">
#          –
#         </span>
#         <span class="job-location">
#          Pasir Ris
#         </span>
#        </div>
#        <div class="quick-apply-badge badge -color-purple">
#         Quick apply
#        </div>
#        <div class="job-abstract">
#         Remove inventory from trucks or shipping and delivery to proper location Update logs and documentation for inventory processing Move materials from...
#        </div>
#        <div class="job-item-bottom-container">
#         <span class="job-listed-date heading-xsmall">
#          1 day ago
#         </span>
#         <button class="tertiary save-job-button" data-disabled="" data-ga-label="serp" data-ga-tracking-func="SavingJob.clicked" data-job-id="e0cb8f4ed4a4021c52f4ce372cd3fad8" data-label-save="Save" data-label-saved="Saved" data-saved="false" data-tk="lvKIqAnmyQ2s3js35RHi-bV8jcoxmTYvlUhNXo5ma" icon="">
#          Save
#         </button>
#        </div>
#       </a>
#      </div>
#      <div id="email-alert-nudge-card">
#       <div class="nudge-card-header">
#        <div class="dismiss" data-close="email-alert-nudge-card">
#        </div>
#       </div>
#       <form accept-charset="UTF-8" action="/email_alerts" class="email-alert-form" data-creation-method="nudge_card" data-registered-user="false" id="nudge_card_new_email_alert" method="post">
#        <input name="utf8" type="hidden" value="✓"/>
#        <input name="authenticity_token" type="hidden" value="XCubi2xRFgWsjZYah9+FiVl+s7nsK123MTPY5kzPzfXMayg6tE0e/hOd7FZmHrxAp1ruUQNjgX4zfnwyuLfSlQ=="/>
#        <h3 class="heading-large" icon="inbox" icon-size="large">
#         Discover new jobs for this search
#        </h3>
#        <p>
#         3 million job seekers receive fresh jobs from Jora daily!
#        </p>
#        <input id="nudge_card_email_alert_radius" name="email_alert[radius]" type="hidden"/>
#        <input id="nudge_card_email_alert_job_type_id" name="email_alert[job_type_id]" type="hidden"/>
#        <input id="nudge_card_email_alert_salary_min" name="email_alert[salary_min]" type="hidden"/>
#        <input id="nudge_card_email_alert_site_id" name="email_alert[site_id]" type="hidden" value="sg"/>
#        <input id="nudge_card_email_alert_creation_method" name="email_alert[creation_method]" type="hidden" value="nudge_card"/>
#        <input id="nudge_card_email_alert_creation_device" name="email_alert[creation_device]" type="hidden" value="desktop"/>
#        <input id="nudge_card_email_alert_creation_platform" name="email_alert[creation_platform]" type="hidden" value="web"/>
#        <input id="nudge_card_email_alert_ignore_identical" name="email_alert[ignore_identical]" type="hidden" value="true"/>
#        <input id="nudge_card_email_alert_query" name="email_alert[query]" type="hidden" value=""/>
#        <input id="nudge_card_email_alert_raw_location" name="email_alert[raw_location]" type="hidden" value="Singapore"/>
#        <input id="nudge_card_email_alert_email" name="email_alert[email]" type="hidden"/>
#        <button class="primary create-alert-button" data-click-origin="nudge_card" data-js-open-suggest-better-alert-modal="true" name="button" type="submit">
#         Create a job alert
#        </button>
#        <div class="privacy-statement heading-xxsmall">
#         By creating an email alert, you agree to Jora's
#         <a href="/cms/terms-of-service">
#          Terms of Service
#         </a>
#         and
#         <a href="/cms/privacy">
#          Privacy Statement
#         </a>
#         . You can cancel email alerts at any time
#        </div>
#       </form>
#      </div>
#      <div class="job-container result organic-job" data-impression-job-type="organic" data-impression-sp="serp" data-job-item="" id="r_0abfe966ab9c490550ad288279924a4e">
#       <a class="job-item" data-ga-label="jobsDB Singapore" data-gtm="view-job" data-rank="5" data-rd="LS0tCjpzcjogNQo6c3A6IHNlcnAKOnNwb25zb3JlZDogZmFsc2UKOnRrOiBsdktJcUFubXlRMnMzanMzNVJIaS1iVjhqY294bVRZdmxVaE5YbzVtYQo=" href="/job/Warehouse-Associate-0abfe966ab9c490550ad288279924a4e?from_url=https%3A%2F%2Fsg.jobsdb.com%2Fj%3Fsp%3Dhomepage%26q%3D%26l%3DSingapore&amp;sl=Singapore&amp;sol_srt=2e2c2e7a-24da-4904-9236-0c732793cbe1&amp;sp=serp&amp;sponsored=false&amp;sq=&amp;sr=5&amp;tk=lvKIqAnmyQ2s3js35RHi-bV8jcoxmTYvlUhNXo5ma" rel="nofollow noopener" target="_blank" title="Warehouse Associate">
#        <div class="job-item-top-container">
#         <h3 class="job-title heading-large -no-margin-bottom">
#          Warehouse Associate
#         </h3>
#         <span class="badge new-job-badge">
#          new
#         </span>
#        </div>
#        <div class="company-location-container heading-small">
#         <span class="job-company">
#          Courts Singapore Pte Ltd
#         </span>
#         <span class="divider">
#          –
#         </span>
#         <span class="job-location">
#          Tampines
#         </span>
#        </div>
#        <div class="quick-apply-badge badge -color-purple">
#         Quick apply
#        </div>
#        <div class="job-abstract">
#         Candidate must possess at least Primary/Secondary School/"O" Level in any field. Required language(s): English Preferably Non-Executive specialized in...
#        </div>
# ...
#        ·
#       </span>
#       <a class="heading-xxsmall -link-highlight" data-sp="facet_location" href="/jobs-in-West" title="West jobs">
#        West
#       </a>
#       <span class="divider">
#        ·
#       </span>
#       <a class="heading-xxsmall -link-highlight" data-sp="facet_location" href="/jobs-in-North" title="North jobs">
#        North
#       </a>
#       <span class="divider">
#        ·
#       </span>
#       <a class="heading-xxsmall -link-highlight" data-sp="facet_location" href="/jobs-in-Tuas" title="Tuas jobs">
#        Tuas
#       </a>
#       <span class="divider">
#        ·
#       </span>
#       <a class="heading-xxsmall -link-highlight" data-sp="facet_location" href="/jobs-in-Outram" title="Outram jobs">
#        Outram
#       </a>
#       <span class="divider">
#        ·
#       </span>
#       <a class="heading-xxsmall -link-highlight" data-sp="facet_location" href="/jobs-in-Woodlands" title="Woodlands jobs">
#        Woodlands
#       </a>
#       <span class="divider">
#        ·
#       </span>
#       <a class="heading-xxsmall -link-highlight" data-sp="facet_location" href="/jobs-in-Jurong-Town" title="Jurong Town jobs">
#        Jurong Town
#       </a>
#       <span class="divider">
#        ·
#       </span>
#       <a class="heading-xxsmall -link-highlight" data-sp="facet_location" href="/jobs-in-Paya-Lebar" title="Paya Lebar jobs">
#        Paya Lebar
#       </a>
#       <span class="divider">
#        ·
#       </span>
#       <a class="heading-xxsmall -link-highlight" data-sp="facet_location" href="/jobs-in-Downtown-Core" title="Downtown Core jobs">
#        Downtown Core
#       </a>
#       <span class="divider">
#        ·
#       </span>
#       <a class="heading-xxsmall -link-highlight" data-sp="facet_location" href="/jobs-in-East" title="East jobs">
#        East
#       </a>
#       <span class="divider">
#        ·
#       </span>
#       <a class="heading-xxsmall -link-highlight" data-sp="facet_location" href="/jobs-in-Kallang" title="Kallang jobs">
#        Kallang
#       </a>
#       <span class="divider">
#        ·
#       </span>
#       <a class="heading-xxsmall -link-highlight" data-sp="facet_location" href="/jobs-in-Changi" title="Changi jobs">
#        Changi
#       </a>
#       <span class="divider">
#        ·
#       </span>
#       <a class="heading-xxsmall -link-highlight" data-sp="facet_location" href="/jobs-in-Geylang" title="Geylang jobs">
#        Geylang
#       </a>
#       <span class="divider">
#        ·
#       </span>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="modal" data-closed="true" data-dismissible="true" id="suggest-better-alert-modal">
#    <div class="modal-wrapper -wide">
#     <div class="modal-header">
#      <div class="dismiss">
#      </div>
#     </div>
#     <div class="modal-content">
#      <form accept-charset="UTF-8" action="/email_alerts" class="email-alert-form suggest-better-alert-form" data-creation-method="suggest_better_alert_modal" id="suggest_better_alert_modal_new_email_alert" method="post">
#       <input name="utf8" type="hidden" value="✓"/>
#       <input name="authenticity_token" type="hidden" value="QSVJNsw9o0cq27WSkZEmX3X/s+LCs0HLcCf8sh3tEljRZfqHFCGrvJXLz95wUB+Wi9vuCi37nQJyalhm6ZUNOA=="/>
#       <h3 class="heading-xlarge" icon="inbox" icon-size="large">
#        Discover new jobs for this search
#       </h3>
#       <p>
#        Stay up to date with new jobs that match what you are looking for.
#       </p>
#       <input id="suggest_better_alert_modal_email_alert_radius" name="email_alert[radius]" type="hidden"/>
#       <input id="suggest_better_alert_modal_email_alert_job_type_id" name="email_alert[job_type_id]" type="hidden"/>
#       <input id="suggest_better_alert_modal_email_alert_salary_min" name="email_alert[salary_min]" type="hidden"/>
#       <input id="suggest_better_alert_modal_email_alert_site_id" name="email_alert[site_id]" type="hidden" value="sg"/>
#       <input id="suggest_better_alert_modal_email_alert_creation_method" name="email_alert[creation_method]" type="hidden" value="suggest_better_alert_modal"/>
#       <input id="suggest_better_alert_modal_email_alert_creation_device" name="email_alert[creation_device]" type="hidden" value="desktop"/>
#       <input id="suggest_better_alert_modal_email_alert_creation_platform" name="email_alert[creation_platform]" type="hidden" value="web"/>
#       <input id="suggest_better_alert_modal_email_alert_ignore_identical" name="email_alert[ignore_identical]" type="hidden" value="true"/>
#       <div class="input-field -visible-label autocomplete-container -highlighted keyword-input-field">
#        <label for="suggest_better_alert_modal_email_alert_query">
#         What
#        </label>
#        <input data-url="/rpc/search_keywords/suggest" icon="search" icon-position="right" id="suggest_better_alert_modal_email_alert_query" maxlength="512" name="email_alert[query]" placeholder="Job title, company, keyword" size="512" type="search" value=""/>
#       </div>
#       <div class="field-description -highlighted" icon="info-small" icon-size="small">
#        Try to be as specific as you can with the job title
#       </div>
#       <div class="input-field -visible-label autocomplete-container location-input-field">
#        <label for="suggest_better_alert_modal_email_alert_raw_location">
#         Where
#        </label>
#        <input data-url="/rpc/search_locations/suggest" icon="location" icon-position="right" id="suggest_better_alert_modal_email_alert_raw_location" maxlength="64" name="email_alert[raw_location]" placeholder="City, district, state" size="64" type="search" value="Singapore"/>
#       </div>
#       <div class="input-field -visible-label">
#        <label for="suggest_better_alert_modal_email_alert_email">
#         Email
#        </label>
#        <input id="suggest_better_alert_modal_email_alert_email" name="email_alert[email]" placeholder="Enter your email" required="required" type="email"/>
#       </div>
#       <button class="primary create-alert-button" data-ga-label="suggest_better_alert_modal" data-ga-tracking-func="EmailAlert.btnClick" data-gtm="create-email-alert" name="button" type="submit">
#        Create a job alert
#       </button>
#       <div class="privacy-statement heading-xxsmall">
#        By creating an email alert, you agree to Jora's
#        <a href="/cms/terms-of-service">
#         Terms of Service
#        </a>
#        and
#        <a href="/cms/privacy">
#         Privacy Statement
#        </a>
#        . You can cancel email alerts at any time
#       </div>
#      </form>
#     </div>
#    </div>
#   </div>
#   <div class="modal" data-closed="true" data-dismissible="true" id="login-modal">
#    <div class="modal-wrapper -thin">
#     <div class="modal-header">
#      <div class="dismiss">
#      </div>
#     </div>
#     <div class="modal-content">
#      <h3 class="heading-large -no-margin-bottom">
#       Sign in to start saving jobs in your profile.
#      </h3>
#      <div class="login-container">
#       <div class="login-form authentication-form">
#        <form accept-charset="UTF-8" action="/users/sign_in" class="new_user" id="save_job_login_modal_new_user" method="post">
#         <input name="utf8" type="hidden" value="✓"/>
#         <input name="authenticity_token" type="hidden" value="Vngmv538mfdOEOfevt1aTtxdGjeNXSSc3JkfnKSN0KXGOJUOReCRDPEAnZJfHGOHInlH32IV+FXe1LtIUPXPxQ=="/>
#         <div class="input-field email-input">
#          <label for="save_job_login_modal_user_email">
#           Email
#          </label>
#          <input icon="email" icon-position="right" id="save_job_login_modal_user_email" name="user[email]" placeholder="Enter your email" required="required" type="email"/>
#         </div>
#         <div class="input-field password-input">
#          <label for="save_job_login_modal_user_password">
#           Password
#          </label>
#          <input icon="password" icon-position="right" id="save_job_login_modal_user_password" name="user[password]" placeholder="Enter password" type="password"/>
#         </div>
#         <input class="button primary" data-disable-with="Log in" data-gtm="start-auth" name="commit" type="submit" value="Log in"/>
#         <a class="button secondary" href="/users/password/new">
#          Forgot your password?
#         </a>
#        </form>
#       </div>
#       <div class="privacy-statement heading-xxsmall">
#        By logging into your account, you agree to Jora's
#        <a href="/cms/terms-of-service">
#         Terms of Service
#        </a>
#        and
#        <a href="/cms/privacy">
#         Privacy Statement
#        </a>
#        .
#       </div>
#       <div class="create-account-prompt">
#        Don’t have a Jora account?
#       </div>
#       <div class="social-login-container">
#        <a class="jora-sign-up" data-gtm="start-auth" href="/users/sign_up" rel="nofollow">
#         <svg height="48" viewbox="0 0 48 48" width="48" xmlns="http://www.w3.org/2000/svg">
#          <g fill="none" fill-rule="evenodd">
#           <circle cx="24" cy="24" fill="#000" r="24">
#           </circle>
#           <path d="M19.113 34.02c-.264 0-.99.33-.99.99 0 .66.726.99.99.99h10.145c.274 0 .99-.33.99-.99 0-.66-.716-.99-.99-.99H19.113z" fill="#338722" fill-rule="nonzero">
#           </path>
#           <path d="M30.35 12.002h-1.921c-.53-.024-.982.148-1.356.515-.562.551-.745.862-.745 1.639v12.532c-.18 1.365-.959 2.047-2.337 2.047-1.378 0-2.12-.682-2.224-2.047v-2.454H18v2.849c0 1.2.045 4.846 5.991 4.707 5.946-.14 6.359-3.483 6.359-4.707v-15.08z" fill="#FFF" fill-rule="nonzero">
#           </path>
#          </g>
#         </svg>
#         <div class="heading-xsmall social-login-text">
#          Create account as a job seeker
#         </div>
#        </a>
#        <a class="facebook-login" data-gtm="start-auth" data-method="post" href="/users/auth/facebook" rel="nofollow">
#         <svg height="48" viewbox="0 0 48 48" width="48" xmlns="http://www.w3.org/2000/svg">
#          <path d="M24 0c13.255 0 24 10.745 24 24S37.255 48 24 48 0 37.255 0 24 10.745 0 24 0zm3.42 12c-3.407 0-5.634 2.064-5.634 5.802v3.285H18v4.311h3.786v10.42c.76.12 1.538.182 2.33.182.793 0 1.571-.062 2.33-.181v-10.42h3.475l.662-4.312h-4.136V18.29c0-1.18.577-2.329 2.43-2.329h1.88v-3.67S29.051 12 27.42 12z" fill="#3B5998" fill-rule="evenodd">
#          </path>
#         </svg>
#         <div class="heading-xsmall social-login-text">
#          Sign in with Facebook
#         </div>
#        </a>
#        <a data-client-id="com.jora.JobsDB.service" data-gtm="start-auth" data-redirect-uri="https://sg.jobsdb.com/sign_in_with_apple_sessions" data-sign-in-with-apple="true" href="#" rel="nofollow">
#         <svg height="48" viewbox="0 0 48 48" width="48" xmlns="http://www.w3.org/2000/svg">
#          <g fill="none" fill-rule="evenodd">
#           <g fill-rule="nonzero">
#            <g transform="translate(-170 -469) translate(170 469)">
#             <rect fill="#000" height="48" rx="24" width="48">
#             </rect>
#             <path d="M24.223 17.385c.832 0 1.875-.58 2.496-1.353.562-.7.972-1.68.972-2.658 0-.132-.011-.265-.035-.374-.926.036-2.039.64-2.707 1.45-.527.615-1.008 1.582-1.008 2.572 0 .145.024.29.036.338.058.013.152.025.246.025zM21.293 32c1.137 0 1.64-.785 3.059-.785 1.441 0 1.757.76 3.023.76 1.242 0 2.074-1.183 2.86-2.342.878-1.33 1.242-2.634 1.265-2.694-.082-.024-2.46-1.027-2.46-3.841 0-2.44 1.874-3.54 1.98-3.624-1.243-1.836-3.13-1.884-3.645-1.884-1.395 0-2.531.87-3.246.87-.774 0-1.793-.822-3-.822-2.297 0-4.629 1.957-4.629 5.653 0 2.295.867 4.723 1.934 6.293.914 1.329 1.71 2.416 2.859 2.416z" fill="#FFF">
#             </path>
#            </g>
#           </g>
#          </g>
#         </svg>
#         <div class="heading-xsmall social-login-text">
#          Sign in with Apple
#         </div>
#        </a>
#        <a class="google-login" data-gtm="start-auth" data-method="post" href="/users/auth/google_oauth2" rel="nofollow">
#         <svg height="48" viewbox="0 0 48 48" width="48" xmlns="http://www.w3.org/2000/svg">
#          <g fill="none" fill-rule="evenodd">
#           <circle cx="24" cy="24" fill="#F7F7F7" r="24">
#           </circle>
#           <g>
#            <path d="M17.64 9.205c0-.639-.057-1.252-.164-1.841H9v3.481h4.844c-.209 1.125-.843 2.078-1.796 2.716v2.259h2.908c1.702-1.567 2.684-3.875 2.684-6.615z" fill="#4285F4" transform="translate(15 15)">
#            </path>
#            <path d="M9 18c2.43 0 4.467-.806 5.956-2.18l-2.908-2.259c-.806.54-1.837.86-3.048.86-2.344 0-4.328-1.584-5.036-3.711H.957v2.332C2.438 15.983 5.482 18 9 18z" fill="#34A853" transform="translate(15 15)">
#            </path>
#            <path d="M3.964 10.71c-.18-.54-.282-1.117-.282-1.71s.102-1.17.282-1.71V4.958H.957C.347 6.173 0 7.548 0 9s.348 2.827.957 4.042l3.007-2.332z" fill="#FBBC05" transform="translate(15 15)">
#            </path>
#            <path d="M9 3.58c1.321 0 2.508.454 3.44 1.345l2.582-2.58C13.463.891 11.426 0 9 0 5.482 0 2.438 2.017.957 4.958L3.964 7.29C4.672 5.163 6.656 3.58 9 3.58z" fill="#EA4335" transform="translate(15 15)">
#            </path>
#           </g>
#          </g>
#         </svg>
#         <div class="heading-xsmall social-login-text">
#          Sign in with Google
#         </div>
#        </a>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <footer>
#    <div class="footer-links content-container -centered -expand-wider">
#     <a class="footer-link" href="/findjobs">
#      Browse jobs
#     </a>
#     <a class="footer-link" href="/popular-searches">
#      Popular searches
#     </a>
#     <a class="footer-link" href="/cms/about">
#      About
#     </a>
#     <a class="footer-link" href="/cms/faq" rel="nofollow">
#      FAQ
#     </a>
#    </div>
#    <hr class="separator"/>
#    <div class="footer-user-action-container">
#     <a class="-link-highlight" href="/login" rel="nofollow">
#      Log in
#     </a>
#    </div>
#    <div class="mobile-app-stores">
#     <a class="app-store-link" href="https://jobsdb.app.link/jobsdbapp_footer">
#      <img alt="Link to App Store" loading="lazy" src="https://jora-assets.jora.com/assets/app-store-logos/app-store-en-2c4d037cb4b180f838fbbb32e0c39fca95a43952c6ce6c59ad60cf29045ce9f1.png"/>
#     </a>
#     <a class="play-store-link" href="https://jobsdb.app.link/jobsdbapp_footer">
#      <img alt="Link to Play Store" loading="lazy" src="https://jora-assets.jora.com/assets/app-store-logos/play-store-en-b32a0f082006882bc619c9564da4ee3706f933f34b26f59c05325d51e3d3289f.png"/>
#     </a>
#    </div>
#    <div class="footer-copyright content-container -centered -expand-wider">
#     ©2021 jobsDB
#    </div>
#   </footer>
#   <script src="https://jora-assets.jora.com/assets/packs/js/application-b19e9722d44203e70bf3.js">
#   </script>
#   <script src="https://jora-assets.jora.com/assets/jora/application-486bde12430766c1d6071a79ddf27769442a8a71b11862f2f0a8e2b29bde8d5e.js">
#   </script>
#   <script charset="utf-8" type="text/javascript">
#    var pageOptions = {
# 'pubId'     : "pub-2856288649011803",
# 'query'     : "Jobs in Singapore",
# 'channel'   : "7963192728",
# 'styleId'   : "6128393078",
# 'adPage'    : 1,
# 'adtest'    : "off",
# 'hl'        : 'en',
# 'linkTarget': '_blank'
# };var adblock1 = {'container':  'top_afs','verticalSpacing':  '12px','fontSizeTitle':  '14px','colorTitleLink':  '#12C','titleBold': false,'noTitleUnderline': true,'fontSizeDomainLink':  '12px','lineHeightDomainLink':  '18px','colorDomainLink':  '#808080','colorText':  '#222','fontSizeDescription':  '12px','domainLinkAboveDescription': false,'maxTop': 2};var adblock2 = {'container':  'bottom_afs','verticalSpacing':  '12px','fontSizeTitle':  '14px','colorTitleLink':  '#12C','titleBold': false,'noTitleUnderline': true,'fontSizeDomainLink':  '12px','lineHeightDomainLink':  '18px','colorDomainLink':  '#808080','colorText':  '#222','fontSizeDescription':  '12px','domainLinkAboveDescription': false,'number': 3};_googCsa('ads', pageOptions, adblock1, adblock2);
#   </script>
#   <script>
#    document.addEventListener('DOMContentLoaded', function() {
#   if (window.solApi) {
#     window.solApi.trackSearch({"keywords":"","pageSize":10,"updatedSince":"3d","sortMode":"RELEVANCE","locations":["Singapore","gadminid:SG"],"totalJobCount":107742,"pageNumber":1});
#     new Midori.SolClickTracker().startTrackingSerpClicks('#jobresults');
#     new Midori.SolImpressionTracker().startTracking();
#   }
# });
#   </script>
#  </body>
# </html>

# %%
job = soup.find('div', class_='job-container result sponsored-job sponsored-top')
print(job.prettify())
# Out:
# <div class="job-container result sponsored-job sponsored-top" data-impression-job-type="sponsored" data-impression-sp="sserp_top" data-job-item="" id="r_a3e0a84cbf477cfc3e76c2e2d25d1aa2">
#  <a class="job-item" data-ga-label="Neuvoo SG" data-gtm="view-job" data-rank="1" data-rd="LS0tCjpzcjogMQo6c3A6IHNzZXJwX3RvcAo6c3BvbnNvcmVkOiB0cnVlCjp0azogbHZLSXFBbm15UTJzM2pzMzVSSGktYlY4amNveG1UWXZsVWhOWG81bWEK" href="/job/rd/a3e0a84cbf477cfc3e76c2e2d25d1aa2?sp=sserp_top&amp;sponsored=true&amp;sr=1&amp;tk=lvKIqAnmyQ2s3js35RHi-bV8jcoxmTYvlUhNXo5ma" rel="nofollow noopener" target="_blank" title="PRIME MOVER DRIVER | $2000 BONUS">
#   <div class="job-item-top-container">
#    <h3 class="job-title heading-large -no-margin-bottom -one-line">
#     PRIME MOVER DRIVER | $2000 BONUS
#    </h3>
#   </div>
#   <div class="company-location-container heading-small">
#    <span class="job-company">
#     Call Lade Enterprises Pte Ltd
#    </span>
#    <span class="divider">
#     –
#    </span>
#    <span class="job-location">
#     Singapore
#    </span>
#   </div>
#   <div class="job-salary-badge badge">
#    $3,000 - $3,700 per month
#   </div>
#   <div class="job-abstract">
#    We are a well-established logistics company located in Pasir Panjang. We aim to maintain a conducive working environment where employees can find...
#   </div>
#   <div class="job-meta">
#    <div class="cite">
#     <span class="sponsor-label">
#      Ad
#     </span>
#     <span class="sponsor-name heading-xsmall">
#      Neuvoo SG
#     </span>
#    </div>
#   </div>
#  </a>
# </div>

# %%
#Get company's name
companyNameContainer = job.find('span', class_='job-company')

companyName = companyNameContainer.text
print(companyName)
# Out:
# Call Lade Enterprises Pte Ltd

# %%
#Get company's title
companyLocationContainer = job.find('span', class_='job-location')

companyLocation = companyLocationContainer.text
print(companyLocation)
# Out:
# Singapore

# %%
#Get job's title
jobTitleContainer = job.find('h3')

jobTitle = jobTitleContainer.text
print(jobTitle)
# Out:
# PRIME MOVER DRIVER | $2000 BONUS

# %%
#Get job's salary
jobSalaryContainer = job.find('div', class_='job-salary-badge badge')

jobSalary = jobSalaryContainer.text
print(jobSalary)
# Out:
# $3,000 - $3,700 per month

# %%
csv_file = open('jobsDB_firstPage', 'w')

csv_writer = csv.writer(csv_file)
csv_writer.writerow(['Company Name', 'Company Location', 'Jon Title', 'Job Salary'])
# Out:
# 52

# %%
for job in soup.find_all('div', class_='job-container result sponsored-job sponsored-top'):
    companyNameContainer = job.find('span', class_='job-company')
    companyName = companyNameContainer.text
    print(companyName)
    
    companyLocationContainer = job.find('span', class_='job-location')
    companyLocation = companyLocationContainer.text
    print(companyLocation)
    
    jobTitleContainer = job.find('h3')
    jobTitle = jobTitleContainer.text
    print(jobTitle)
    
    try:
        jobSalaryContainer = job.find('div', class_='job-salary-badge badge')
        jobSalary = jobSalaryContainer.text
    except Exception as e:
        jobSalary = None
        
    print(jobSalary)
    
    print()
    
    csv_writer.writerow([companyName, companyLocation, jobTitle, jobSalary])
# Out:
# Call Lade Enterprises Pte Ltd
# Singapore
# PRIME MOVER DRIVER | $2000 BONUS
# $3,000 - $3,700 per month
#
# Octavius Finance
# Singapore
# Power Market Analyst (Renewable Energy, Carbon & Climate change) - Singapore
# None

# %%
for job in soup.find_all('div', class_='job-container result organic-job'):
    companyNameContainer = job.find('span', class_='job-company')
    companyName = companyNameContainer.text
    print(companyName)
    
    companyLocationContainer = job.find('span', class_='job-location')
    companyLocation = companyLocationContainer.text
    print(companyLocation)
    
    jobTitleContainer = job.find('h3')
    jobTitle = jobTitleContainer.text
    print(jobTitle)
    
    try:
        jobSalaryContainer = job.find('div', class_='job-salary-badge badge')
        jobSalary = jobSalaryContainer.text
    except Exception as e:
        jobSalary = None
        
    print(jobSalary)
    
    print()
    
    csv_writer.writerow([companyName, companyLocation, jobTitle, jobSalary])
# Out:
# Sejong Korean Language School
# Downtown Core
# PART-TIME OFFICE ASSISTANT (8-MONTH TEMPORARY JOB)
# None
#
# Maraicar Agency
# Geylang
# Admin Assistant
# None
#
# Weissach Motors Pte Ltd
# Bedok
# Admin Assistant
# None
#
# Thinktrek Logistics Pte Ltd
# Pasir Ris
# Warehouse Assistant
# None
#
# Courts Singapore Pte Ltd
# Tampines
# Warehouse Associate
# None
#
# Lab Services Pte Ltd
# Geylang
# Lab Assistant
# None
#
# Fujisan Enterprise Pte Ltd
# Bedok
# Warehouse Assistant
# None
#
# ER Marketing (S) Pte Ltd
# Sembawang
# Admin Assistant
# None
#
# Road Husky Transport Pte Ltd
# Geylang
# Warehouse Assistant
# None
#
# Querios Pte. Ltd.
# Jurong Town
# Packer
# None

# %%
for job in soup.find_all('div', class_='job-container result sponsored-job sponsored-bottom'):
    companyNameContainer = job.find('span', class_='job-company')
    companyName = companyNameContainer.text
    print(companyName)
    
    companyLocationContainer = job.find('span', class_='job-location')
    companyLocation = companyLocationContainer.text
    print(companyLocation)
    
    jobTitleContainer = job.find('h3')
    jobTitle = jobTitleContainer.text
    print(jobTitle)
    
    try:
        jobSalaryContainer = job.find('div', class_='job-salary-badge badge')
        jobSalary = jobSalaryContainer.text
    except Exception as e:
        jobSalary = None
        
    print(jobSalary)
    
    print()
    
    csv_writer.writerow([companyName, companyLocation, jobTitle, jobSalary])
    
csv_file.close()
# Out:
# J.P.Morgan
# Singapore
# MAC Site Reliability Engineer, Associate
# None
#
# TEKsystems (Allegis Group Singapore Pte Ltd)
# Singapore
# Radio Network Planner
# None
#
# TEKsystems (Allegis Group Singapore Pte Ltd)
# Singapore
# Cloud Developer
# None
